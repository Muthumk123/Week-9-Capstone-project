# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
import pickle
import pandas as pd
from sklearn.model_selection import train_test_split 
import numpy as np

# %%
df=pd.read_csv("Preprocessdheart_dis.csv")

# %%
with open("Final_model_for_capstoneproject.pkl", "rb") as f:
    model = pickle.load(f)

# %%
user_input = []
for i in range(20):
    val = float(input(f"Feature {i+1}: "))
    user_input.append(val)
    user_input = np.array(user_input).reshape(1, -1)
    break
# Out:
# Feature 1:  20

# %%
user_input_scaled = StandardScaler.transform(np.array(user_input).reshape(1, -1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 user_input_scaled = StandardScaler.transform(np.array(user_input).reshape(1, -1))
#
# TypeError: StandardScaler.transform() missing 1 required positional argument: 'X'

# %%
prediction = model.predict(user_input_scaled)

# %%
if prediction[0] == 1:
    print("Heart Disease Positive")
else:
    print("Heart Disease Negative")
